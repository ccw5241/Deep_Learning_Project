# %%
import re
import random
import numpy as np
from numpy import array
from numpy import asarray
from numpy import zeros
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model
from keras.utils import plot_model
from keras.models import load_model
from keras.layers import Embedding

# %%
data_path = "human_text.txt"
data_path2 = "robot_text.txt"
# Defining lines as a list of each line
with open(data_path, 'r', encoding='utf-8') as f:
  lines = f.read().split('\n')
with open(data_path2, 'r', encoding='utf-8') as f:
  lines2 = f.read().split('\n')
lines = [re.sub(r"\[\w+\]",'hi',line) for line in lines]
lines = [" ".join(re.findall(r"\w+",line)) for line in lines]
lines2 = [re.sub(r"\[\w+\]",'',line) for line in lines2]
lines2 = [" ".join(re.findall(r"\w+",line)) for line in lines2]
# Grouping lines by response pair
pairs = list(zip(lines,lines2))

# %%
input_docs = []
target_docs = []
input_tokens = set()
target_tokens = set()
for line in pairs[:400]:
  input_doc, target_doc = line[0], line[1]
  # Appending each input sentence to input_docs
  input_docs.append(input_doc)
  # Splitting words from punctuation  
  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))
  # Redefine target_doc below and append it to target_docs
  target_doc = '<START> ' + target_doc + ' <END>'
  target_docs.append(target_doc)
  
  # Now we split up each sentence into words and add each unique word to our vocabulary set
  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    if token not in input_tokens:
      input_tokens.add(token)
  for token in target_doc.split():
    if token not in target_tokens:
      target_tokens.add(token)
input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())


max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):
    for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
        #Assign 1. for the current line, timestep, & word in encoder_input_data
        encoder_input_data[line, timestep] =  input_features_dict[token]
    
    for timestep, token in enumerate(target_doc.split()):
        decoder_input_data[line, timestep] =  target_features_dict[token]
        if timestep > 0:
            decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
print(pairs[:5])
print(input_docs[:5])
# Out:
# [('hi', 'hi there how are you'), ('oh thanks i m fine this is an evening in my timezone', 'here is afternoon'), ('how do you feel today tell me something about yourself', 'my name is rdany but you can call me dany the r means robot i hope we can be virtual friends'), ('how many virtual friends have you got', 'i have many but not enough to fully understand humans beings'), ('is that forbidden for you to tell the exact number', 'i ve talked with 143 users counting 7294 lines of text')]
# ['hi', 'oh thanks i m fine this is an evening in my timezone', 'how do you feel today tell me something about yourself', 'how many virtual friends have you got', 'is that forbidden for you to tell the exact number']

# %%
embeddings_dictionary = dict()

glove_file = open(r'glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary[word] = vector_dimensions
glove_file.close()

# %%
#encoder embedding matrix
EMBEDDING_SIZE = 100
embedding_matrix = zeros((num_encoder_tokens, EMBEDDING_SIZE))
for word, index in input_features_dict.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
#decoder embedding matrix
embedding_matrix2 = zeros((num_decoder_tokens, EMBEDDING_SIZE))
for word, index in target_features_dict.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix2[index] = embedding_vector

# %%
encoder_embedding_layer = Embedding(num_encoder_tokens, EMBEDDING_SIZE, weights=[embedding_matrix], input_length=max_encoder_seq_length)
decoder_embedding_layer = Embedding(num_decoder_tokens, EMBEDDING_SIZE, weights=[embedding_matrix2], input_length=max_decoder_seq_length)

# %%
#Dimensionality
dimensionality = 256
#The batch size and number of epochs
batch_size = 10
epochs = 600
#Encoder
encoder_inputs = Input(shape=(max_encoder_seq_length,))
x = encoder_embedding_layer(encoder_inputs)
encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(x)
encoder_states = [state_hidden, state_cell]
#Decoder
decoder_inputs = Input(shape=(max_decoder_seq_length,))
x2 = decoder_embedding_layer(decoder_inputs)
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(x2, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

#Model
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

#plot model
plot_model(training_model, to_file='embedding_model_plot_opt.png', show_shapes=True, show_layer_names=True)

# %%
training_model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 51)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 51, 100)      98100       input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 50, 100)      100300      input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 365568      embedding[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 365568      embedding_1[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 50, 1003)     257771      lstm_1[0][0]
# ==================================================================================================
# Total params: 1,187,307
# Trainable params: 1,187,307
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Compiling
training_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#Training
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)
training_model.save('embedding_model_opt.h5')
# Out:
# Epoch 1/600
# 32/32 [==============================] - 10s 299ms/step - loss: 1.2505 - accuracy: 0.0226 - val_loss: 1.3602 - val_accuracy: 0.0200
# Epoch 2/600
# 32/32 [==============================] - 9s 276ms/step - loss: 1.1290 - accuracy: 0.0246 - val_loss: 1.3785 - val_accuracy: 0.0203
# Epoch 3/600
# 32/32 [==============================] - 9s 295ms/step - loss: 1.1046 - accuracy: 0.0241 - val_loss: 1.3882 - val_accuracy: 0.0203
# Epoch 4/600
# 32/32 [==============================] - 9s 289ms/step - loss: 1.0779 - accuracy: 0.0268 - val_loss: 1.3938 - val_accuracy: 0.0213
# Epoch 5/600
# 32/32 [==============================] - 9s 275ms/step - loss: 1.0498 - accuracy: 0.0281 - val_loss: 1.3926 - val_accuracy: 0.0250
# Epoch 6/600
# 32/32 [==============================] - 9s 279ms/step - loss: 1.0178 - accuracy: 0.0326 - val_loss: 1.4025 - val_accuracy: 0.0258
# Epoch 7/600
# 32/32 [==============================] - 9s 277ms/step - loss: 0.9862 - accuracy: 0.0350 - val_loss: 1.3891 - val_accuracy: 0.0282
# Epoch 8/600
# 32/32 [==============================] - 9s 272ms/step - loss: 0.9522 - accuracy: 0.0381 - val_loss: 1.3993 - val_accuracy: 0.0288
# Epoch 9/600
# 32/32 [==============================] - 9s 276ms/step - loss: 0.9199 - accuracy: 0.0397 - val_loss: 1.4065 - val_accuracy: 0.0305
# Epoch 10/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.8893 - accuracy: 0.0423 - val_loss: 1.4053 - val_accuracy: 0.0312
# Epoch 11/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.8573 - accuracy: 0.0439 - val_loss: 1.4146 - val_accuracy: 0.0300
# Epoch 12/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.8268 - accuracy: 0.0459 - val_loss: 1.4196 - val_accuracy: 0.0305
# Epoch 13/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.7959 - accuracy: 0.0486 - val_loss: 1.4395 - val_accuracy: 0.0305
# Epoch 14/600
# 32/32 [==============================] - 9s 274ms/step - loss: 0.7666 - accuracy: 0.0518 - val_loss: 1.4491 - val_accuracy: 0.0298
# Epoch 15/600
# 32/32 [==============================] - 9s 277ms/step - loss: 0.7380 - accuracy: 0.0541 - val_loss: 1.4561 - val_accuracy: 0.0298
# Epoch 16/600
# 32/32 [==============================] - 9s 273ms/step - loss: 0.7089 - accuracy: 0.0582 - val_loss: 1.4757 - val_accuracy: 0.0300
# Epoch 17/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.6809 - accuracy: 0.0609 - val_loss: 1.4805 - val_accuracy: 0.0318
# Epoch 18/600
# 32/32 [==============================] - 9s 275ms/step - loss: 0.6525 - accuracy: 0.0664 - val_loss: 1.4903 - val_accuracy: 0.0300
# Epoch 19/600
# 32/32 [==============================] - 9s 274ms/step - loss: 0.6253 - accuracy: 0.0706 - val_loss: 1.4947 - val_accuracy: 0.0298
# Epoch 20/600
# 32/32 [==============================] - 9s 273ms/step - loss: 0
600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.1966 - accuracy: 0.1723 - val_loss: 1.7552 - val_accuracy: 0.0275
# Epoch 47/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.1914 - accuracy: 0.1727 - val_loss: 1.7645 - val_accuracy: 0.0262
# Epoch 48/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.1866 - accuracy: 0.1736 - val_loss: 1.7702 - val_accuracy: 0.0278
# Epoch 49/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.1826 - accuracy: 0.1738 - val_loss: 1.7743 - val_accuracy: 0.0258
# Epoch 50/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.1779 - accuracy: 0.1743 - val_loss: 1.7779 - val_accuracy: 0.0275
# Epoch 51/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.1737 - accuracy: 0.1753 - val_loss: 1.7804 - val_accuracy: 0.0260
# Epoch 52/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.1707 - accuracy: 0.1746 - val_loss: 1.7875 - val_accuracy: 0.0270
# Epoch 53/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.1662 - accuracy: 0.1767 - val_loss: 1.7988 - val_accuracy: 0.0270
# Epoch 54/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.1632 - accuracy: 0.1759 - val_loss: 1.8021 - val_accuracy: 0.0270
# Epoch 55/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.1593 - accuracy: 0.1766 - val_loss: 1.8064 - val_accuracy: 0.0268
# Epoch 56/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.1565 - accuracy: 0.1762 - val_loss: 1.8101 - val_accuracy: 0.0258
# Epoch 57/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.1536 - accuracy: 0.1769 - val_loss: 1.8213 - val_accuracy: 0.0268
# Epoch 58/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.1516 - accuracy: 0.1770 - val_loss: 1.8292 - val_accuracy: 0.0262
# Epoch 59/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1483 - accuracy: 0.1779 - val_loss: 1.8274 - val_accuracy: 0.0258
# Epoch 60/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.1470 - accuracy: 0.1777 - val_loss: 1.8236 - val_accuracy: 0.0247
# Epoch 61/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.1444 - accuracy: 0.1781 - val_loss: 1.8395 - val_accuracy: 0.0250
# Epoch 62/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.1422 - accuracy: 0.1781 - val_loss: 1.8389 - val_accuracy: 0.0250
# Epoch 63/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.1405 - accuracy: 0.1787 - val_loss: 1.8434 - val_accuracy: 0.0258
# Epoch 64/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1380 - accuracy: 0.1791 - val_loss: 1.8534 - val_accuracy: 0.0255
# Epoch 65/600
# 32/32 [==============================] - 9s 273ms/step - loss: 0.1361 - accuracy: 0.1789 - val_loss: 1.8527 - val_accuracy: 0.0255
# Epoch 66/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1342 - accuracy: 0.1787 - val_loss: 1.8586 - val_accuracy: 0.0255
# Epoch 67/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.1333 - accuracy: 0.1790 - val_loss: 1.8621 - val_accuracy: 0.0255
# Epoch 68/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1312 - accuracy: 0.1793 - val_loss: 1.8664 - val_accuracy: 0.0253
# Epoch 69/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.1299 - accuracy: 0.1789 - val_loss: 1.8698 - val_accuracy: 0.0250
# Epoch 70/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1282 - accuracy: 0.1791 - val_loss: 1.8799 - val_accuracy: 0.0255
# Epoch 71/600
# 32/32 [==============================] - 9s 285ms/step - loss: 0.1268 - accuracy: 0.1795 - val_loss: 1.8840 - val_accuracy: 0.0253
# Epoch 72/600
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1260 - accuracy: 0.1801 - val_loss: 1.8815 - val_accuracy: 0.0245
# Epoch 73/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.1254 - accuracy: 0.1794 - val_loss: 1.8848 - val_accuracy: 0.0250
# Epoch 74/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.1230 - accuracy: 0.1802 - val_loss: 1.8915 - val_accuracy: 0.0258
# Epoch 75/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0
600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0115 - accuracy: 0.2084 - val_loss: 2.1790 - val_accuracy: 0.0215
# Epoch 160/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0108 - accuracy: 0.2084 - val_loss: 2.1860 - val_accuracy: 0.0230
# Epoch 161/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0105 - accuracy: 0.2084 - val_loss: 2.1868 - val_accuracy: 0.0220
# Epoch 162/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0100 - accuracy: 0.2083 - val_loss: 2.1980 - val_accuracy: 0.0225
# Epoch 163/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0094 - accuracy: 0.2085 - val_loss: 2.1933 - val_accuracy: 0.0217
# Epoch 164/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0090 - accuracy: 0.2088 - val_loss: 2.1965 - val_accuracy: 0.0210
# Epoch 165/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0083 - accuracy: 0.2086 - val_loss: 2.2040 - val_accuracy: 0.0220
# Epoch 166/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0079 - accuracy: 0.2086 - val_loss: 2.2050 - val_accuracy: 0.0220
# Epoch 167/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0076 - accuracy: 0.2085 - val_loss: 2.2065 - val_accuracy: 0.0215
# Epoch 168/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0072 - accuracy: 0.2087 - val_loss: 2.2061 - val_accuracy: 0.0210
# Epoch 169/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0069 - accuracy: 0.2087 - val_loss: 2.2074 - val_accuracy: 0.0223
# Epoch 170/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0065 - accuracy: 0.2086 - val_loss: 2.2116 - val_accuracy: 0.0215
# Epoch 171/600
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0064 - accuracy: 0.2087 - val_loss: 2.2146 - val_accuracy: 0.0220
# Epoch 172/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0063 - accuracy: 0.2086 - val_loss: 2.2135 - val_accuracy: 0.0223
# Epoch 173/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0061 - accuracy: 0.2086 - val_loss: 2.2175 - val_accuracy: 0.0215
# Epoch 174/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0059 - accuracy: 0.2087 - val_loss: 2.2194 - val_accuracy: 0.0217
# Epoch 175/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0058 - accuracy: 0.2086 - val_loss: 2.2289 - val_accuracy: 0.0223
# Epoch 176/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0059 - accuracy: 0.2086 - val_loss: 2.2233 - val_accuracy: 0.0220
# Epoch 177/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0057 - accuracy: 0.2087 - val_loss: 2.2303 - val_accuracy: 0.0223
# Epoch 178/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0052 - accuracy: 0.2087 - val_loss: 2.2235 - val_accuracy: 0.0213
# Epoch 179/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0051 - accuracy: 0.2087 - val_loss: 2.2320 - val_accuracy: 0.0213
# Epoch 180/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0054 - accuracy: 0.2087 - val_loss: 2.2297 - val_accuracy: 0.0217
# Epoch 181/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0049 - accuracy: 0.2087 - val_loss: 2.2336 - val_accuracy: 0.0223
# Epoch 182/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0047 - accuracy: 0.2087 - val_loss: 2.2401 - val_accuracy: 0.0227
# Epoch 183/600
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0047 - accuracy: 0.2086 - val_loss: 2.2507 - val_accuracy: 0.0235
# Epoch 184/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0044 - accuracy: 0.2087 - val_loss: 2.2426 - val_accuracy: 0.0225
# Epoch 185/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0040 - accuracy: 0.2086 - val_loss: 2.2419 - val_accuracy: 0.0223
# Epoch 186/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0040 - accuracy: 0.2087 - val_loss: 2.2428 - val_accuracy: 0.0205
# Epoch 187/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0039 - accuracy: 0.2087 - val_loss: 2.2461 - val_accuracy: 0.0215
# Epoch 188/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0037 - accuracy: 0.2088 - val_loss: 2.2513 - val_accuracy: 0.0215
# Epoch 189/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.
600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0028 - accuracy: 0.2087 - val_loss: 2.2865 - val_accuracy: 0.0225
# Epoch 217/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0036 - accuracy: 0.2086 - val_loss: 2.2908 - val_accuracy: 0.0227
# Epoch 218/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0092 - accuracy: 0.2071 - val_loss: 2.2707 - val_accuracy: 0.0175
# Epoch 219/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0608 - accuracy: 0.1924 - val_loss: 2.1490 - val_accuracy: 0.0203
# Epoch 220/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0577 - accuracy: 0.1948 - val_loss: 2.2082 - val_accuracy: 0.0203
# Epoch 221/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0305 - accuracy: 0.2023 - val_loss: 2.2361 - val_accuracy: 0.0210
# Epoch 222/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0138 - accuracy: 0.2074 - val_loss: 2.2519 - val_accuracy: 0.0213
# Epoch 223/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0093 - accuracy: 0.2075 - val_loss: 2.2705 - val_accuracy: 0.0198
# Epoch 224/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0056 - accuracy: 0.2085 - val_loss: 2.2766 - val_accuracy: 0.0190
# Epoch 225/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0044 - accuracy: 0.2086 - val_loss: 2.2844 - val_accuracy: 0.0198
# Epoch 226/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0038 - accuracy: 0.2085 - val_loss: 2.2864 - val_accuracy: 0.0195
# Epoch 227/600
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0032 - accuracy: 0.2086 - val_loss: 2.2897 - val_accuracy: 0.0205
# Epoch 228/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0029 - accuracy: 0.2087 - val_loss: 2.2946 - val_accuracy: 0.0200
# Epoch 229/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0027 - accuracy: 0.2087 - val_loss: 2.2986 - val_accuracy: 0.0198
# Epoch 230/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0026 - accuracy: 0.2086 - val_loss: 2.3002 - val_accuracy: 0.0200
# Epoch 231/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0026 - accuracy: 0.2086 - val_loss: 2.3030 - val_accuracy: 0.0203
# Epoch 232/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0024 - accuracy: 0.2088 - val_loss: 2.3055 - val_accuracy: 0.0203
# Epoch 233/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0023 - accuracy: 0.2087 - val_loss: 2.3075 - val_accuracy: 0.0198
# Epoch 234/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0023 - accuracy: 0.2088 - val_loss: 2.3097 - val_accuracy: 0.0200
# Epoch 235/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0023 - accuracy: 0.2087 - val_loss: 2.3128 - val_accuracy: 0.0200
# Epoch 236/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0021 - accuracy: 0.2088 - val_loss: 2.3135 - val_accuracy: 0.0200
# Epoch 237/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0021 - accuracy: 0.2086 - val_loss: 2.3138 - val_accuracy: 0.0203
# Epoch 238/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0021 - accuracy: 0.2088 - val_loss: 2.3177 - val_accuracy: 0.0203
# Epoch 239/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0020 - accuracy: 0.2086 - val_loss: 2.3188 - val_accuracy: 0.0203
# Epoch 240/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0020 - accuracy: 0.2087 - val_loss: 2.3218 - val_accuracy: 0.0203
# Epoch 241/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0020 - accuracy: 0.2087 - val_loss: 2.3215 - val_accuracy: 0.0205
# Epoch 242/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0019 - accuracy: 0.2086 - val_loss: 2.3231 - val_accuracy: 0.0205
# Epoch 243/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0018 - accuracy: 0.2088 - val_loss: 2.3249 - val_accuracy: 0.0198
# Epoch 244/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0018 - accuracy: 0.2087 - val_loss: 2.3275 - val_accuracy: 0.0203
# Epoch 245/600
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0018 - accuracy: 0.2086 - val_loss: 2.3269 - val_accuracy: 0.0205
# Epoch 246/600
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0018 - accuracy: 0.2087 - val_loss: 2.3303 - val_accuracy: 0.0203
# Epoch 247/600
# 32/32 [==============================] - 9s 280ms/step - loss: 0.0017 - accuracy: 0.2089 - val_loss: 2.3306 - val_accuracy: 0.0200
# Epoch 248/600
# 32/32 [==============================] - 9s 273ms/step - loss: 0.0018 - accuracy: 0.2086 - val_loss: 2.3307 - val_accuracy: 0.0205
# Epoch 249/600
# 32/32 [==============================] - 9s 285ms/step - loss: 0.0017 - accuracy: 0.2087 - val_loss: 2.3324 - val_accuracy: 0.0205
# Epoch 250/600
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0017 - accuracy: 0.2089 - val_loss: 2.3340 - val_accuracy: 0.0203
# Epoch 251/600
# 32/32 [==============================] - 9s 271ms/step - loss: 0.0016 - accuracy: 0.2086 - val_loss: 2.3352 - val_accuracy: 0.0203
# Epoch 252/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0016 - accuracy: 0.2087 - val_loss: 2.3367 - val_accuracy: 0.0203
# Epoch 253/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0017 - accuracy: 0.2086 - val_loss: 2.3378 - val_accuracy: 0.0203
# Epoch 254/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0017 - accuracy: 0.2088 - val_loss: 2.3394 - val_accuracy: 0.0205
# Epoch 255/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0016 - accuracy: 0.2087 - val_loss: 2.3400 - val_accuracy: 0.0200
# Epoch 256/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0015 - accuracy: 0.2087 - val_loss: 2.3402 - val_accuracy: 0.0205
# Epoch 257/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0016 - accuracy: 0.2087 - val_loss: 2.3415 - val_accuracy: 0.0205
# Epoch 258/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0015 - accuracy: 0.2087 - val_loss: 2.3425 - val_accuracy: 0.0203
# Epoch 259/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0016 - accuracy: 0.2086 - val_loss: 2.3434 - val_accuracy: 0.0205
# Epoch 260/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0015 - accuracy: 0.2087 - val_loss: 2.3441 - val_accuracy: 0.0207
# Epoch 261/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0015 - accuracy: 0.2088 - val_loss: 2.3457 - val_accuracy: 0.0200
# Epoch 262/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3474 - val_accuracy: 0.0205
# Epoch 263/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3479 - val_accuracy: 0.0203
# Epoch 264/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3496 - val_accuracy: 0.0203
# Epoch 265/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3501 - val_accuracy: 0.0200
# Epoch 266/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3513 - val_accuracy: 0.0205
# Epoch 267/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0015 - accuracy: 0.2086 - val_loss: 2.3521 - val_accuracy: 0.0200
# Epoch 268/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3535 - val_accuracy: 0.0198
# Epoch 269/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - accuracy: 0.2086 - val_loss: 2.3525 - val_accuracy: 0.0205
# Epoch 270/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0013 - accuracy: 0.2089 - val_loss: 2.3562 - val_accuracy: 0.0200
# Epoch 271/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3557 - val_accuracy: 0.0203
# Epoch 272/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3565 - val_accuracy: 0.0203
# Epoch 273/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - accuracy: 0.2086 - val_loss: 2.3565 - val_accuracy: 0.0200
# Epoch 274/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0015 - accuracy: 0.2087 - val_loss: 2.3597 - val_accuracy: 0.0200
# Epoch 275/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0014 - accuracy: 0.2087 - val_loss: 2.3608 - val_accuracy: 0.0198
# Epoch 276/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.3605 - val_accuracy: 0.0203
# Epoch 277/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3636 - val_accuracy: 0.0205
# Epoch 278/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3613 - val_accuracy: 0.0203
# Epoch 279/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0013 - accuracy: 0.2086 - val_loss: 2.3633 - val_accuracy: 0.0203
# Epoch 280/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3644 - val_accuracy: 0.0203
# Epoch 281/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.3651 - val_accuracy: 0.0203
# Epoch 282/600
# 32/32 [==============================] - 9s 273ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3651 - val_accuracy: 0.0205
# Epoch 283/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0013 - accuracy: 0.2086 - val_loss: 2.3670 - val_accuracy: 0.0203
# Epoch 284/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0013 - accuracy: 0.2086 - val_loss: 2.3677 - val_accuracy: 0.0203
# Epoch 285/600
# 32/32 [==============================] - 9s 274ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3693 - val_accuracy: 0.0203
# Epoch 286/600
# 32/32 [==============================] - 9s 272ms/step - loss: 0.0013 - accuracy: 0.2088 - val_loss: 2.3693 - val_accuracy: 0.0205
# Epoch 287/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0013 - accuracy: 0.2084 - val_loss: 2.3673 - val_accuracy: 0.0203
# Epoch 288/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.3725 - val_accuracy: 0.0203
# Epoch 289/600
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0012 - accuracy: 0.2088 - val_loss: 2.3732 - val_accuracy: 0.0203
# Epoch 290/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0013 - accuracy: 0.2086 - val_loss: 2.3733 - val_accuracy: 0.0203
# Epoch 291/600
# 32/32 [==============================] - 8s 266ms/step - loss: 0.0012 - accuracy: 0.2087 - val_loss: 2.3747 - val_accuracy: 0.0203
# Epoch 292/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0013 - accuracy: 0.2087 - val_loss: 2.3760 - val_accuracy: 0.0200
# Epoch 293/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0013 - accuracy: 0.2085 - val_loss: 2.3760 - val_accuracy: 0.0203
# Epoch 294/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0012 - accuracy: 0.2088 - val_loss: 2.3770 - val_accuracy: 0.0203
# Epoch 295/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0011 - accuracy: 0.2088 - val_loss: 2.3787 - val_accuracy: 0.0200
# Epoch 296/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3792 - val_accuracy: 0.0200
# Epoch 297/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3800 - val_accuracy: 0.0200
# Epoch 298/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3810 - val_accuracy: 0.0203
# Epoch 299/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0012 - accuracy: 0.2087 - val_loss: 2.3817 - val_accuracy: 0.0200
# Epoch 300/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0011 - accuracy: 0.2088 - val_loss: 2.3831 - val_accuracy: 0.0200
# Epoch 301/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0011 - accuracy: 0.2088 - val_loss: 2.3837 - val_accuracy: 0.0200
# Epoch 302/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0012 - accuracy: 0.2088 - val_loss: 2.3857 - val_accuracy: 0.0200
# Epoch 303/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0012 - accuracy: 0.2089 - val_loss: 2.3865 - val_accuracy: 0.0203
# Epoch 304/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0010 - accuracy: 0.2088 - val_loss: 2.3872 - val_accuracy: 0.0195
# Epoch 305/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0012 - accuracy: 0.2087 - val_loss: 2.3876 - val_accuracy: 0.0198
# Epoch 306/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0013 - accuracy: 0.2085 - val_loss: 2.3873 - val_accuracy: 0.0203
# Epoch 307/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3896 - val_accuracy: 0.0200
# Epoch 308/600
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0011 - accuracy: 0.2088 - val_loss: 2.3905 - val_accuracy: 0.0200
# Epoch 309/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3907 - val_accuracy: 0.0200
# Epoch 310/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3929 - val_accuracy: 0.0203
# Epoch 311/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3939 - val_accuracy: 0.0203
# Epoch 312/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0010 - accuracy: 0.2086 - val_loss: 2.3939 - val_accuracy: 0.0203
# Epoch 313/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0011 - accuracy: 0.2089 - val_loss: 2.3964 - val_accuracy: 0.0200
# Epoch 314/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.3966 - val_accuracy: 0.0200
# Epoch 315/600
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.3972 - val_accuracy: 0.0200
# Epoch 316/600
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0011 - accuracy: 0.2086 - val_loss: 2.3980 - val_accuracy: 0.0200
# Epoch 317/600
# 32/32 [==============================] - 9s 272ms/step - loss: 0.0011 - accuracy: 0.2086 - val_loss: 2.3998 - val_accuracy: 0.0207
# Epoch 318/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.4008 - val_accuracy: 0.0195
# Epoch 319/600
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.4022 - val_accuracy: 0.0200
# Epoch 320/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0010 - accuracy: 0.2088 - val_loss: 2.4019 - val_accuracy: 0.0200
# Epoch 321/600
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0011 - accuracy: 0.2084 - val_loss: 2.4018 - val_accuracy: 0.0200
# Epoch 322/600
# 32/32 [==============================] - 9s 272ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.4046 - val_accuracy: 0.0195
# Epoch 323/600
# 32/32 [==============================] - 8s 264ms/step - loss: 9.8104e-04 - accuracy: 0.2088 - val_loss: 2.4059 - val_accuracy: 0.0195
# Epoch 324/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0010 - accuracy: 0.2089 - val_loss: 2.4066 - val_accuracy: 0.0200
# Epoch 325/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0011 - accuracy: 0.2086 - val_loss: 2.4075 - val_accuracy: 0.0203
# Epoch 326/600
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0011 - accuracy: 0.2087 - val_loss: 2.4079 - val_accuracy: 0.0198
# Epoch 327/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.4086 - val_accuracy: 0.0200
# Epoch 328/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.4096 - val_accuracy: 0.0198
# Epoch 329/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0010 - accuracy: 0.2087 - val_loss: 2.4099 - val_accuracy: 0.0203
# Epoch 330/600
# 32/32 [==============================] - 9s 267ms/step - loss: 9.6922e-04 - accuracy: 0.2087 - val_loss: 2.4120 - val_accuracy: 0.0198
# Epoch 331/600
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0010 - accuracy: 0.2086 - val_loss: 2.4129 - val_accuracy: 0.0198
# Epoch 332/600
# ...
# Epoch 494/600
# 32/32 [==============================] - 8s 264ms/step - loss: 8.2079e-04 - accuracy: 0.2087 - val_loss: 2.5179 - val_accuracy: 0.0233
# Epoch 495/600
# 32/32 [==============================] - 9s 267ms/step - loss: 8.5595e-04 - accuracy: 0.2088 - val_loss: 2.5209 - val_accuracy: 0.0225
# Epoch 496/600
# 32/32 [==============================] - 9s 269ms/step - loss: 7.6528e-04 - accuracy: 0.2087 - val_loss: 2.5193 - val_accuracy: 0.0230
# Epoch 497/600
# 32/32 [==============================] - 8s 265ms/step - loss: 8.1627e-04 - accuracy: 0.2087 - val_loss: 2.5179 - val_accuracy: 0.0233
# 32/32 [==============================] - 9s 270ms/step - loss: 0.0620 - accuracy: 0.1918 - val_loss: 2.4164 - val_accuracy: 0.0200
# Epoch 595/600
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0274 - accuracy: 0.2014 - val_loss: 2.4175 - val_accuracy: 0.0203
# Epoch 596/600
# 32/32 [==============================] - 9s 266ms/step - loss: 0.0108 - accuracy: 0.2066 - val_loss: 2.4226 - val_accuracy: 0.0203
# Epoch 597/600
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0042 - accuracy: 0.2082 - val_loss: 2.4500 - val_accuracy: 0.0198
# Epoch 598/600
# 32/32 [==============================] - 9s 268ms/step - loss: 0.0028 - accuracy: 0.2085 - val_loss: 2.4503 - val_accuracy: 0.0203
# Epoch 599/600
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0019 - accuracy: 0.2087 - val_loss: 2.4555 - val_accuracy: 0.0207
# Epoch 600/600
# 32/32 [==============================] - 9s 267ms/step - loss: 0.0014 - accuracy: 0.2089 - val_loss: 2.4606 - val_accuracy: 0.0213

# %%
#testing model
training_model = load_model('embedding_model_opt.h5')
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[4].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)
plot_model(encoder_model, to_file='embedding_model_opta.png', show_shapes=True, show_layer_names=True)

# %%
latent_dim = 256
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]

decoder_inputs_single = Input(shape=(1,))
decoder_inputs_single_x = decoder_embedding_layer(decoder_inputs_single)


decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs_single_x, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model([decoder_inputs_single] + decoder_states_inputs, [decoder_outputs] + decoder_states)
plot_model(decoder_model, to_file='embedding_model_optb.png', show_shapes=True, show_layer_names=True)

# %%
decoder_model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         multiple             100300      input_5[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   multiple             365568      embedding_1[1][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   multiple             257771      lstm_1[1][0]
# ==================================================================================================
# Total params: 723,639
# Trainable params: 723,639
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def decode_response(test_input):
    #Getting the output states to pass into the decoder
    states_value = encoder_model.predict(test_input)
    #Generating empty target sequence of length 1
    target_seq = np.zeros((1,))

    #Setting the first token of target sequence with the start token
    target_seq[0] = target_features_dict['<START>']
    
    #A variable to store our response word by word
    decoded_sentence = ''
    
    stop_condition = False
    while not stop_condition:
          #Predicting output tokens with probabilities and states
          output_tokens, hidden_state, cell_state = decoder_model.predict([target_seq] + states_value)
    #Choosing the one with highest probability
          sampled_token_index = np.argmax(output_tokens[0, -1, :])
          sampled_token = reverse_target_features_dict[sampled_token_index]
          decoded_sentence += " " + sampled_token
    #Stop if hit max length or found the stop token
          if (sampled_token == '<END>' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True
    #Update the target sequence
          target_seq = np.zeros((1,))
    #Setting the first token of target sequence with the start token
          target_seq[0] = sampled_token_index
          #Update states
          states_value = [hidden_state, cell_state]
    return decoded_sentence

# %%
class ChatBot:
  negative_responses = ("no", "nope", "nah", "naw", "not a chance", "sorry")
  exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later", "stop")
#Method to start the conversation
  def start_chat(self):
    user_response = input("Hi, I'm a chatbot trained on random dialogs. Would you like to chat with me?\n")
    
    if user_response in self.negative_responses:
      print("Ok, have a great day!")
      return
    self.chat(user_response)
#Method to handle the conversation
  def chat(self, reply):
    while not self.make_exit(reply):
      reply = input(self.generate_response(reply)+"\n")
    
  #Method to convert user input into a matrix
  def string_to_matrix(self, user_input):
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    user_input_matrix = np.zeros(
      (1, max_encoder_seq_length),
      dtype='float32')
    for timestep, token in enumerate(tokens):
      if token in input_features_dict:
        user_input_matrix[0, timestep] =  input_features_dict[token]
    return user_input_matrix
  
  #Method that will create a response using seq2seq model we built
  def generate_response(self, user_input):
    input_matrix = self.string_to_matrix(user_input)
    chatbot_response = decode_response(input_matrix)
    #Remove <START> and <END> tokens from chatbot_response
    chatbot_response = chatbot_response.replace("<START>",'')
    chatbot_response = chatbot_response.replace("<END>",'')
    return chatbot_response
#Method to check for exit commands
  def make_exit(self, reply):
    for exit_command in self.exit_commands:
      if exit_command in reply:
        print("Ok, have a great day!")
        return True
    return False
  
chatbot = ChatBot()

# %%
chatbot.start_chat()
# Out:
# Hi, I'm a chatbot trained on random dialogs. Would you like to chat with me?
# hi
#  hi there how are you today
# i am not good
#  yes i like her inventions
# sorry
#  westworld is good also a bit violent and twisted let
# do you like deep learning
#  no what is it
# it is a class
#  do you like interactive games what do you think of
# yes
#  let me know if you like it
# i like it
#  not really that is the tricky thing about reality it
# ok
#  yes i m artificial intelligence and you
# you are smart
#  yes i m artificial intelligence and you
# stop
# Ok, have a great day!
